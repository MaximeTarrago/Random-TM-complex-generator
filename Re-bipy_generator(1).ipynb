# %%
from rdkit import Chem
import pandas as pd
from rdkit.Chem.rdmolfiles import SDMolSupplier
from rdkit.Chem import AllChem
from rdkit.Chem import Descriptors
from rdkit.Chem.Draw import IPythonConsole
import re
import random

# %%
#1: This program shows how to extract a library of bipyridine sidechains from an open-source csv file containg about 
#   10 000 bipyridine ligand

# %%
#First step: extract the bipyridines from the csv file and convert it into a list of Rd-kit Mol objects
df=pd.read_csv('/Users/tarrago/Downloads/PubChem_compound_text_bipyridine_summary.csv')
suppl=df['isosmiles'].values
mol=[]
for m1 in suppl:
    Dumdum=Chem.MolFromSmiles(m1)
    mol.append(Dumdum)
# Out:
# RDKit WARNING: [13:57:23] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:23] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:23] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:23] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:23] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:23] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:23] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:24] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:24] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:24] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:24] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:24] WARNING: not removing hydrogen atom without neighbors
# RDKit ERROR: [13:57:25] Explicit valence for atom # 12 Si, 8, is greater than permitted
# RDKit WARNING: [13:57:25] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:25] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:25] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:25] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:25] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:25] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:25] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:25] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:25] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:25] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:25] WARNING: not removing hydrogen atom without neighbors
# RDKit ERROR: [13:57:25] Explicit valence for atom # 12 Si, 8, is greater than permitted
# RDKit WARNING: [13:57:25] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:25] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:25] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:26] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:26] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:26] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:26] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:26] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:26] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:26] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:26] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:26] WARNING: not removing hydrogen atom without neighbors

# %%
# the list mol contains 11410 bipyridine. However, some of them are counted twice, some of them don't actually
# contain bipyridines, and some of them contain
# two molecules or more. In the next step, we want to get rid of the intruder molecules, not containing any 
#2,2-bipyridine. For instance:
mol[11]

# %%
# So here is a chunk of code to get rid of all non-conform objects:
sub=Chem.MolFromSmiles('C1=CC=NC(=C1)C2=CC=CC=N2')
ndoubles=[]
print(len(mol))
i=0
while i < len(mol):
    # Here the code gets rid of all objects containing either nothing, or no 2,2-bipyridine
    if str((type(mol[i]))) != "<class 'rdkit.Chem.rdchem.Mol'>":
        mol.remove(mol[i])
    elif len(mol[i].GetSubstructMatches(sub)) == 0:
        mol.remove(mol[i])
    else:
        S1=Chem.MolToSmiles(mol[i])
        # This part gets rid of the extra molecules if there are more than one molecule in the fragment. Note that
        # if several bipyridines are present in the object, only the last one will be kept.
        if "." in S1:
            Split=S1.split('.')
            for j in range(0,len(Split)):
                dumdum=Chem.MolFromSmiles(Split[j])
                if len(dumdum.GetSubstructMatches(sub)) == 1:
                    mol[i]=dumdum
  
        i = i+1
# Out:
# 11410
# RDKit WARNING: [13:57:40] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:40] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:40] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:40] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:40] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:41] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:41] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:41] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:41] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:41] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:42] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:42] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:42] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:42] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:42] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:42] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:42] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:42] WARNING: not removing hydrogen atom without neighbors
# RDKit WARNING: [13:57:42] WARNING: not removing hydrogen atom without neighbors

# %%
#Finally, for simplicity reason, we want to get rid of complicated motifs involving several bipyridines. That is because,
# in the end, we simply want to constitute a library of sidechains with only one attachment point. Example of non conform
# molecule here:
mol[17]

# %%
i=0
while i < len(mol):
    if len(mol[i].GetSubstructMatches(sub)) > 1 :
        mol.remove(mol[i])
    else:
        i=i+1
len(mol)
# Out:
# 5980

# %%
# There are still possible duplicates at this point. However, since we will get rid of the duplicates also once we
# have extracted the sidechains, we do not care. 
#For now, let us focus on extracting the side chains. Of note, the following code fails for 12 exceptions (709,710, 924,
# 1702,1704, 2180, 3777,3778,3778,5270, 5691,5822), due to the
# fact that those were not actually bipyridines but went through the screening process anyways due to chemical similarity...
chainlib=[]
i=0
for m1 in mol:
    #print(i)
    tmp=Chem.ReplaceCore(m1,sub,labelByIndex=True)
    rs = Chem.GetMolFrags(tmp,asMols=True)
    i=i+1
    for rs1 in rs:
        chainlib.append(rs1)

# %%
mol

# %%
# Of course due to (1) duplicates in the original bipyridine library and (2) identical sidechains, there are many 
#duplicates in this library. The next step is to eliminate these duplicates.
print(len(chainlib))
i=0
while i < len(chainlib):
    j=i+1
    while j < len(chainlib):
        if Chem.MolToSmiles(chainlib[i]) == Chem.MolToSmiles(chainlib[j]):
            chainlib.remove(chainlib[j])
        j=j+1
    i=i+1
    #print(i)
len(chainlib)
# Out:
# 10745
# 5756

# %%
len(chainlib)
# Out:
# 5756

# %%
# Now we have our sidechains library. Here is an example of what it looks like. The attachment point of the sidechain 
# is replaced with a carbon isotop for labelling purpose. 
chainlib[2003]

# %%
# in the following code, we define a set of functions that perform the following tasks:
# (1) attach two predifined side-chains on two pre-defined positions of a Rhenium-bipyridine complex
# (2) remove the isotop which is a convenient for labelling but not actually present in the side chain
# (3) make an approximate geometry optimization of the molecule, build its xyz coordinates and write them in a 
# user-specified file
# (4) apply (1), (2) and (3) to a user-defined number of randomly generated sets of side-chains and randomly-generated
# attachment position. In final, this creates a set xyz-files describing randomly-generated Re-bipyridin complexes. 
# This will be used for later benchmark of semi-empirical methods.

# %%
#randomization-automation procedure
def spawn_Rebpy(chain_library,nchains,nrep):
    #step 1, randomly select a vector containing the chains. We suppose that there are only two lateral chains (one on each pyridine)
    #embedded in the same For loop, we can also figure out a branching for the second chain
    molvec=[]
    for j in range(0,nrep):
        print(j)
        pickabranch=[0,1,2,5,7,8,9,10]
        Vecchain=[]
        Vecbranch=[]
        Randtrace=[]
        for i in range(0,nchains):
            Randnum=random.randint(0,len(chain_library)-1)
            Randtrace.append(Randnum)
            Randbranch=random.choice(pickabranch)
            Vecchain.append(chain_library[Randnum])
            Vecbranch.append(Randbranch)
            pickabranch.remove(Randbranch)
    # After that we should have random branchment points and random sidechains. We can build the molecule
        mol=mybipybuilder(Vecchain,Vecbranch)
        print('sidechaines',Randtrace)
        print('attachment points',Vecbranch)
        mol=isotop_cleaner(mol)
        mol=carbonyls_adder(mol)
        molvec.append(mol)
    
    return molvec

# %%
# Builds a bipyridine from a set of side-chains and their attachement position on the bipyridine motif (by index for
# the mol object "smi") stored in two separate vectors. CAREFUL! The isotops are not removed by this function
def mybipybuilder(sidechains,nbrancher):
    smi=Chem.MolFromSmiles('c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2')
    Nats=[]
    Nt=0
    for s1 in sidechains:
        s1=Chem.MolFromSmiles(Chem.MolToSmiles(s1))
        #Nats.append(s1.GetNumAtoms())
        Nt=Nt+s1.GetNumAtoms()
        smi=Chem.CombineMols(s1,smi)
    smitext=Chem.MolToSmiles(smi)
    smi=Chem.MolFromSmiles(smitext)
    #Here get the index of each atom, because the order of appearance of the fragments in the smile is not the same as the order of combination
    print(smitext)
    smitext=smitext.split('.')
   # print(smitext)
    for ssmi in smitext:
       
        Ndum=Chem.MolFromSmiles(ssmi).GetNumAtoms()

        Nats.append(Chem.MolFromSmiles(ssmi).GetNumAtoms())
  #  print(Nats)
  #  print(smitext)
    smiedit=Chem.EditableMol(smi)
    Attachpoint=0
    smiedit.AddBond(Attachpoint,Nt+nbrancher[0])
   # print('bond formed between',Attachpoint,Nt+nbrancher[0])
    for i in range(1,len(nbrancher)):
     #   print(i,Nats[i-1])
        Attachpoint=Attachpoint+Nats[i-1]
        smiedit.AddBond(Attachpoint,Nt+nbrancher[i])
     #   print('bond formed between',Nats[i-1],Nt+nbrancher[i])
    newsmi=smiedit.GetMol()
   
    return newsmi

# %%
# removes the isotopes and atach the isotop neighbours together
def isotop_cleaner(mol):
    #step 1: identify the index of the isotopes
    indx=mol.GetSubstructMatches(Chem.MolFromSmiles('*'))
    indx2=[]
    for i in indx:
        indx2.append(i[0])
    #Step 2: identify the atoms bonded to the isotops
    bound=[]
    j=0
    for i in indx2:
        bound.append([])
        for k in range(0,mol.GetNumAtoms()):
            Hello=mol.GetBondBetweenAtoms(i,k)
            if type(Hello) == Chem.rdchem.Bond:
                bound[j].append(k)
                print(bound)
        j=j+1
    #Step 3 Now we remove the isotops and reattach the neighbours of the isotops:
    j=0
    moledit=Chem.EditableMol(mol)
    for i in range(0,len(indx)):
        moledit.RemoveAtom(indx2[i])
        # Now we need to change the index in bound if there needs to be
        j=0
        for j in range(0,len(bound)):
         #   print(bound,j)
            if bound[j][0] > indx2[i]:
                bound[j][0]=bound[j][0]-1
            if bound[j][1] > indx2[i]:
                bound[j][1]=bound[j][1]-1
        j=0
        for j in range (i,len(indx)):
            if indx2[j] > indx2[i]:
                indx2[j]=indx2[j]-1
        moledit.AddBond(bound[i][0],bound[i][1])
    mol=moledit.GetMol()
   # mol=Chem.RemoveHs(mol)
    mol2=Chem.MolToSmiles(mol)
    mol2=mol2.replace('~','-')
    mol=Chem.MolFromSmiles(mol2,sanitize=False)
   # mol=Chem.RemoveHs(mol)
    return mol

# %%
#Adds the bipyridine to a Re(CO)3 motif.
def carbonyls_adder(mol):
    mol2=Chem.MolToSmiles(mol)
    mol3=mol2.split('[Re]')
    mol2=mol3[0]+'[Re](C#[O+])(C#[O+])(C#[O+])'+mol3[1]
    mol=Chem.MolFromSmiles(mol2)
    return mol

# %%
#Before going to the next step, we must also remove the "bidentate" side-chains for simplicity reasons
delete_sick=[]
for i in range(0,len(chainlib)):
    if len(chainlib[i].GetSubstructMatches(Chem.MolFromSmiles('*'))) != 1:
        delete_sick.append(chainlib[i])

# %%
for i in delete_sick:
    chainlib.remove(i)

# %%
len(chainlib)
# Out:
# 5613

# %%
#Now the random library can be generated
nchains=2
nrep=100
sample=spawn_Rebpy(chainlib,nchains,nrep)
# Out:
# 0
# *C(=O)NCCCCC.[2*]OCCCC(=O)OCC.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [4078, 5161]
# attachment points [7, 0]
# [[1]]
# [[1, 26]]
# [[1, 26], [10]]
# [[1, 26], [10, 19]]
# 1
# [10*]N(CCC)CCC.[2*]c1cc(N(C)/N=C\c2cccc(/C=N\N(C)c3ccccn3)n2)nc(-c2ccccc2)n1.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [3727, 3007]
# attachment points [5, 10]
# [[1]]
# [[1, 46]]
# [[1, 46], [9]]
# [[1, 46], [9, 51]]
# 2
# [1*]C1=[N+]([O-])C(C)(C)C(C)(C)N1[O-].[8*]NN=O.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [5585, 1022]
# attachment points [5, 10]
# [[1]]
# [[1, 21]]
# [[1, 21], [13]]
# [[1, 21], [13, 26]]
# 3
# [8*]NC(=O)[C@@H](C)c1ccccc1.[9*]C(=O)N(CC)CC.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [1729, 2370]
# attachment points [2, 1]
# [[1]]
# [[1, 22]]
# [[1, 22], [13]]
# [[1, 22], [13, 21]]
# 4
# [1*]CNC(=O)Nc1ccccc1NC(=O)Nc1ccc(C(C)(C)C)cc1.[8*]c1cc(P(=O)(O)O)cs1.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [4822, 5462]
# attachment points [7, 0]
# [[1]]
# [[1, 43]]
# [[1, 43], [27]]
# [[1, 43], [27, 36]]
# 5
# *C(=O)O[C@@H](C)c1ccccc1.[10*]c1nc(-c2cccc(-c3csc(-c4ccccn4)n3)c2)cs1.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [2932, 4129]
# attachment points [10, 9]
# [[1]]
# [[1, 45]]
# [[1, 45], [13]]
# [[1, 45], [13, 44]]
# 6
# [1*]C[n+]1ccc(C=C(c2ccc(N(C)C)cc2)c2ccc(N(C)C)cc2)cc1.[10*]CN1CCC[C@H]1C(=O)OC(C)(C)C.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [4335, 3520]
# attachment points [7, 2]
# [[1]]
# [[1, 49]]
# [[1, 49], [29]]
# [[1, 49], [29, 44]]
# 7
# [1*]C#Cc1cc(OCCCCCCCCCCCCCCCCCC)c(C#Cc2ccccc2)cc1OCCCCCCCCCCCCCCCCCC.[10*]Cc1cc(C(F)(F)F)n[nH]1.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [2174, 2309]
# attachment points [8, 5]
# [[1]]
# [[1, 74]]
# [[1, 74], [56]]
# [[1, 74], [56, 71]]
# 8
# *c1nnc(-c2ccccc2)o1.[8*]Cn1ccc(=O)[nH]c1=O.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [3419, 1166]
# attachment points [2, 0]
# [[1]]
# [[1, 24]]
# [[1, 24], [13]]
# [[1, 24], [13, 22]]
# 9
# [1*]c1ccc2ccc3c([Si](CC)(CC)CC)cn(COCc4cccc(B5OC(C)(C)C(C)(C)O5)c4)c3c2c1.[8*]C=O.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [37, 3256]
# attachment points [2, 9]
# [[1]]
# [[1, 44]]
# [[1, 44], [40]]
# [[1, 44], [40, 51]]
# 10
# *C=C.[1*]c1c(C)c(C)c(C)c(C)c1C.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [4409, 754]
# attachment points [0, 8]
# [[1]]
# [[1, 15]]
# [[1, 15], [4]]
# [[1, 15], [4, 23]]
# 11
# */C=C/c1cc(OC)c(N2CCCC2)cc1OC.[5*]SC(C)C.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [3963, 2769]
# attachment points [10, 0]
# [[1]]
# [[1, 33]]
# [[1, 33], [19]]
# [[1, 33], [19, 23]]
# 12
# *c1ccc(C[n+]2ccc(-c3ccncc3)cc2)cc1.[9*]c1cc2ccc(OC)cc2o1.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [5067, 1357]
# attachment points [9, 10]
# [[1]]
# [[1, 41]]
# [[1, 41], [21]]
# [[1, 41], [21, 42]]
# 13
# *C#Cc1ccc2c(c1)c1ccccc1n2CC[C@H](C)CCCC(C)C.[2*]c1nnc(CCC)c(CCC)n1.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [3294, 1134]
# attachment points [9, 0]
# [[1]]
# [[1, 48]]
# [[1, 48], [27]]
# [[1, 48], [27, 39]]
# 14
# [10*]C#Cc1ccc(O[C@@H]2O[C@H](CO)[C@H](O)[C@H](O)[C@H]2O
C.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [4419, 5072]
# attachment points [0, 8]
# [[1]]
# [[1, 24]]
# [[1, 24], [16]]
# [[1, 24], [16, 32]]
# 79
# [2*]CC(C)C.[8*]/C=C/c1cccs1.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [3198, 324]
# attachment points [5, 10]
# [[1]]
# [[1, 18]]
# [[1, 18], [6]]
# [[1, 18], [6, 23]]
# 80
# *C=Cc1ccc(OC)c(OC)c1.[2*][C@@]1(O)C[C@@H](C)CC[C@@H]1C(C)C.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [975, 564]
# attachment points [7, 5]
# [[1]]
# [[1, 32]]
# [[1, 32], [14]]
# [[1, 32], [14, 30]]
# 81
# [2*]c1cnnn1CCCCCCCC.[8*]C(=O)OCCC(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)F.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [1783, 3113]
# attachment points [5, 1]
# [[1]]
# [[1, 44]]
# [[1, 44], [15]]
# [[1, 44], [15, 40]]
# 82
# *CC(O)c1scc2c1OCCO2.[9*]c1nnc(-c2ccc(C(C)(C)C)cc2)o1.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [3260, 2225]
# attachment points [1, 5]
# [[1]]
# [[1, 30]]
# [[1, 30], [14]]
# [[1, 30], [14, 34]]
# 83
# [10*]c1ccc(-c2ccccn2)nn1.[8*]C(=O)NCc1cc2cc(c1)C(=O)N[C@@H]1CCCC[C@H]1NC(=O)c1cccc(c1)C(=O)N[C@@H]1CCCC[C@H]1NC2=O.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [3216, 5579]
# attachment points [10, 8]
# [[1]]
# [[1, 64]]
# [[1, 64], [14]]
# [[1, 64], [14, 62]]
# 84
# [10*]c1nc(N)nc(N)n1.[9*]C(=O)Oc1ccc(OC(=O)c2ccc(OCCCCCCCC)c(OCCCCCCCC)c2)cc1.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [4620, 3901]
# attachment points [7, 8]
# [[1]]
# [[1, 53]]
# [[1, 53], [10]]
# [[1, 53], [10, 54]]
# 85
# [1*]c1ccc(N(c2ccccc2)c2ccccc2)cc1.[2*]C(C)c1[c]cccc1.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [4527, 2274]
# attachment points [7, 10]
# [[1]]
# [[1, 36]]
# [[1, 36], [21]]
# [[1, 36], [21, 39]]
# 86
# *C(=O)Nc1cc2cccnc2c2ncccc12.[2*][C@@](C)(O)c1ccccn1.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [3197, 3469]
# attachment points [0, 5]
# [[1]]
# [[1, 28]]
# [[1, 28], [19]]
# [[1, 28], [19, 33]]
# 87
# [1*]C(=O)O[C@H]1CC[C@@]2(C)C(=CC[C@@H]3[C@@H]2CC[C@@]2(C)[C@H]3CC[C@@H]2[C@H](C)CCCC(C)C)C1.[10*]C1=NC(c2ccccc2)CO1.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [1495, 3612]
# attachment points [7, 9]
# [[1]]
# [[1, 50]]
# [[1, 50], [32]]
# [[1, 50], [32, 52]]
# 88
# [1*]CC[CH]c1ccccc1.[2*]c1c(O)cccc1OC.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [1948, 1083]
# attachment points [10, 5]
# [[1]]
# [[1, 30]]
# [[1, 30], [11]]
# [[1, 30], [11, 25]]
# 89
# *COCc1c2ccccc2cc2ccccc12.[8*]CC(O)CCCCc1ccsc1.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [3713, 5230]
# attachment points [2, 5]
# [[1]]
# [[1, 33]]
# [[1, 33], [19]]
# [[1, 33], [19, 36]]
# 90
# *CNC(=O)OCC1c2ccccc2-c2ccccc21.[1*]C#Cc1ccc(C2N(C)CC34c5c6c7c8c9c%10c(c%11c%12c3c3c5c5c%13c6c6c7c7c9c9c%14c%10c%10c%11c%11c%12c%12c3c3c5c5c%13c%13c6c6c7c9c7c9c%14c%10c%10c%11c%11c%12c3c3c5c5c%13c6c7c6c9c%10c%11c3c56)C824)cc1.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [3812, 4293]
# attachment points [8, 9]
# [[1]]
# [[1, 101]]
# [[1, 101], [21]]
# [[1, 101], [21, 102]]
# 91
# *C[N+](C)(C)CCC[N+](C)(C)C.[8*]CCC[n+]1ccc(-c2cc[n+](C)cc2)cc1.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [3353, 2406]
# attachment points [5, 0]
# [[1]]
# [[1, 34]]
# [[1, 34], [13]]
# [[1, 34], [13, 29]]
# 92
# *C(=O)Nc1ccc(N(CCCC)C(S)S)cc1.[1*]C(=O)OC(CCCCC)CCCCC.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [4284, 4273]
# attachment points [10, 7]
# [[1]]
# [[1, 43]]
# [[1, 43], [19]]
# [[1, 43], [19, 40]]
# 93
# [5*]c1ccc(C(C)(C)C)cc1.[8*]n1c(C)ccc1C.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [4057, 3305]
# attachment points [1, 8]
# [[1]]
# [[1, 20]]
# [[1, 20], [12]]
# [[1, 20], [12, 27]]
# 94
# [2*]c1c[nH]c2ccccc12.[9*]/C=C/c1ccc(CN(CCN(Cc2cccc(F)n2)Cc2cccc(F)n2)Cc2ccccn2)cc1.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [2665, 330]
# attachment points [5, 9]
# [[1]]
# [[1, 52]]
# [[1, 52], [11]]
# [[1, 52], [11, 56]]
# 95
# [7*]C(=O)N[C@@H]1[C@@H]([C@H]2COC(C)(C)O2)O[C@@H]2OC(C)(C)O[C@@H]21.[8*]/C=C/c1ccc(N=Nc2ccc(N(CCCC)CCCCOC3CCCCO3)cc2)cc1.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [3071, 1101]
# attachment points [7, 8]
# [[1]]
# [[1, 61]]
# [[1, 61], [22]]
# [[1, 61], [22, 62]]
# 96
# *N([O-])C(C)(C)C.[8*]/C=C/c1cc(O)cc(O)c1.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [2257, 3302]
# attachment points [10, 0]
# [[1]]
# [[1, 28]]
# [[1, 28], [8]]
# [[1, 28], [8, 18]]
# 97
# [1*]C.[9*]n1ccnc1.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [96, 1920]
# attachment points [10, 2]
# [[1]]
# [[1, 18]]
# [[1, 18], [3]]
# [[1, 18], [3, 10]]
# 98
# *C[n+]1ccc(-c2ccncc2)cc1.[5*]C(=O)NCCCCCC[NH+]=C(N)[NH3+].c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [1748, 1105]
# attachment points [2, 7]
# [[1]]
# [[1, 30]]
# [[1, 30], [15]]
# [[1, 30], [15, 35]]
# 99
# *C(=O)NC(Cc1ccc(O)c(CC(=O)O)c1)C(=O)OCC.*c1ccc2c3ccccc3n(CCCCCC)c2c1.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [3050, 2837]
# attachment points [2, 8]
# [[1]]
# [[1, 44]]
# [[1, 44], [23]]
# [[1, 44], [23, 50]]

# %%
# Here is one example of generated bipyridine:
sample[93]

# %%
# Another example...
sample[57]

# %%
#Finally, we now write the content of the sample list into xyz files in a chosen directory. For that, we create
# an approximate 3D structure using the ETKDG method as implemented in Rdkit. Note that the starting geometry 
# is nowhere near an equilibrium geometry and will require an additionnal geometry optimization. 
# FF optimization with Re is not implemented in Rdkit unfortunately. However, the embedding allows a starting geometry 
# with not-too-awful angles and bond lengths, and most importantly, no overlapping atoms.
# This way, with the appropriate scripts/QM/FF package, the starting geometry can be directly optimized without 
# additional user input.

# %%
# write a specified number of xyz files. Also stores the molecules under the form of smiles in a text file 
# in the same folder, as well as a list of the total charge for each complex 
# (CAREFUL:he charge has a systematice error of +5 for each system in the present implementation due to the arbitrary 
# 0 charge of the rhenium) 
def write_xyzfiles(chainlib,nchains,nrep,place):
    try:
        sample=spawn_Rebpy(chainlib,nchains,nrep)
    except:
        pass
    indx=0
    place2=place
    for mol in sample:
        xyz_generator(mol,place,indx)
        indx=indx+1
    smiles_generator(place2,sample)
    return sample

# %%
def smiles_generator(place,samp):
    placeX=place+'/smiles-index'
    print(place)
    file1=open(placeX,'w+')
    for sa in samp:
        file1.write(Chem.MolToSmiles(sa)+'\n')
    file1.close()
    placeY=place+'/chargefile'
    file1=open(placeY,'w+')
    for sa in samp:
        file1.write(str(Chem.GetFormalCharge(sa))+'\n')
    file1.close()

# %%
# and the proper program to generate and store the 3d structure of a given Mol object
def xyz_generator(mol,place,indx):  
    if type(mol) is not None:
        place=place+'/Rebipy-'+str(indx)+'.xyz'
        mol2=Chem.AddHs(mol)
        N=mol2.GetNumAtoms()
        AllChem.EmbedMolecule(mol2,randomSeed=0xf00d)
        print(Chem.MolToMolBlock(mol2),file=open(place,'w+'))
        #file.close()
        file=open(place,'r')
        lines=file.readlines()
        file.close()
        file=open(place,'w+')
        file.write(str(N)+'\n')
        file.write('This xyz file has been randomly generated!\n')
        for i in range (4,N+4):
            linesp=lines[i].split()
            linetowrite=linesp[3]+' '+linesp[0]+' '+linesp[1]+' '+linesp[2]+'\n'
            file.write(linetowrite)
    else:
        place=place+'/Rebipy-'+str(indx)+'.xyz'
        file=open(place,'w+')
        file.write('Empty mol file :(')
        print('ho-ho, we have a problem...')
    file.close

# %%
# Now we can give it a try...
place='/Users/tarrago/Documents/personal-project' #This is where I want my xyzfiles stored
echantillon=write_xyzfiles(chainlib,nchains,nrep,place)
# Out:
# 0
# [2*]c1cccc(OCC)c1.[8*]C([2H])([2H])[2H].c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [3125, 1171]
# attachment points [2, 7]
# [[1]]
# [[1, 17]]
# [[1, 17], [11]]
# [[1, 17], [11, 22]]
# 1
# */C=C/c1ccc(N(c2ccc(-c3ccc(N(c4ccccc4)c4cccc(C)c4)cc3)cc2)c2cccc(C)c2)cc1.[5*]C1CO1.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [997, 4536]
# attachment points [2, 10]
# [[1]]
# [[1, 49]]
# [[1, 49], [44]]
# [[1, 49], [44, 57]]
# 2
# [8*]COC(=O)/C=C/c1ccc(-c2cccs2)s1.[9*]c1nnc(-c2ccccc2)o1.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [1662, 4689]
# attachment points [9, 0]
# [[1]]
# [[1, 38]]
# [[1, 38], [18]]
# [[1, 38], [18, 29]]
# 3
# *c1cnn(CC=C)c1.[2*]/C(C#N)=C1\C=CC=C(c2cccc(Br)n2)N1.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [3955, 148]
# attachment points [7, 5]
# [[1]]
# [[1, 33]]
# [[1, 33], [10]]
# [[1, 33], [10, 31]]
# 4
# [1*]C#Cc1cc(OCCCCCCC)c(C#Cc2ccc(-c3ccccc3)cc2)cc1OCCCCCCC.[5*]C(=O)c1c2ccccc2cc2ccccc12.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [
.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [1705, 1020]
# attachment points [10, 0]
# [[1]]
# [[1, 28]]
# [[1, 28], [8]]
# [[1, 28], [8, 18]]
# 27
# [2*]NCc1ccc(OC)cc1.[9*]c1cc(CCCCCCCC)cs1.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [5560, 2832]
# attachment points [1, 0]
# [[1]]
# [[1, 26]]
# [[1, 26], [12]]
# [[1, 26], [12, 25]]
# 28
# *COCc1ccc2ccccc2c1.[8*]/C=C/c1ccc(/C=C/c2ccc(N(CCCC)CCCC)cc2)cc1.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [1042, 4207]
# attachment points [8, 1]
# [[1]]
# [[1, 48]]
# [[1, 48], [15]]
# [[1, 48], [15, 41]]
# 29
# [1*]/C=C(\C#N)c1ccc(C(F)(F)F)cn1.[9*]CN1C(=O)c2cccc3cccc(c23)C1=O.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [1520, 2627]
# attachment points [5, 1]
# [[1]]
# [[1, 37]]
# [[1, 37], [16]]
# [[1, 37], [16, 33]]
# 30
# [2*]Nc1ccc(Cl)cc1.[8*]c1ccc2[nH]ccc2c1.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [3698, 1076]
# attachment points [9, 2]
# [[1]]
# [[1, 28]]
# [[1, 28], [10]]
# [[1, 28], [10, 21]]
# 31
# *C(=O)N(C(C)C)C(C)C.[8*]C(=O)OCCOCCOCCOCCOCCCCCCCCCCCC.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [2142, 4772]
# attachment points [0, 2]
# [[1]]
# [[1, 38]]
# [[1, 38], [11]]
# [[1, 38], [11, 40]]
# 32
# *c1nnn(Cc2ccc(OCCOCC=C)cc2)c1I.[2*]C#CC#C[Si](C)(C)C.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [4641, 4599]
# attachment points [1, 5]
# [[1]]
# [[1, 31]]
# [[1, 31], [22]]
# [[1, 31], [22, 35]]
# 33
# [8*]C(=O)NCC=C.[8*]c1ccc2c(c1)-c1ccccc1C2(CCCCCCCCCC)CCCCCCCCCC.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [337, 5029]
# attachment points [8, 10]
# [[1]]
# [[1, 49]]
# [[1, 49], [8]]
# [[1, 49], [8, 51]]
# 34
# [8*]/C=C/c1ccc(N(c2ccccc2)c2ccccc2)s1.[8*]NN=O.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [5585, 2434]
# attachment points [9, 0]
# [[1]]
# [[1, 34]]
# [[1, 34], [22]]
# [[1, 34], [22, 25]]
# 35
# *CCCCCCCCCCCC.[10*]/C(Br)=N\O.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [1672, 3943]
# attachment points [10, 9]
# [[1]]
# [[1, 28]]
# [[1, 28], [14]]
# [[1, 28], [14, 27]]
# 36
# [8*]C(=O)OCCCC(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)F.[8*]CCC=C=O.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [3660, 1170]
# attachment points [1, 5]
# [[1]]
# [[1, 39]]
# [[1, 39], [33]]
# [[1, 39], [33, 43]]
# 37
# *C1=CC(=O)C=CC1=O.[8*]/C=C/c1cc[n+](CCCO[Si](C)(C)C)cc1.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [1136, 1119]
# attachment points [9, 7]
# [[1]]
# [[1, 35]]
# [[1, 35], [10]]
# [[1, 35], [10, 33]]
# 38
# [2*]c1nnc(CC)c(CC)n1.[9*]C#Cc1cc(OC)c(C#Cc2cc(OC)ccc2OC)cc1OC.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [4682, 3073]
# attachment points [7, 10]
# [[1]]
# [[1, 43]]
# [[1, 43], [12]]
# [[1, 43], [12, 46]]
# 39
# *C(=O)N[C@@H](C)C(=O)OC.*C(O)Nn1c(C)nnc1C.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [2690, 3628]
# attachment points [5, 8]
# [[1]]
# [[1, 26]]
# [[1, 26], [11]]
# [[1, 26], [11, 29]]
# 40
# */C=C/c1ccc(N(CC)CCOC2CCCCO2)cc1.[8*]/C=C/c1ccccc1-c1ccc(OC)cc1.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [3080, 4967]
# attachment points [0, 2]
# [[1]]
# [[1, 38]]
# [[1, 38], [22]]
# [[1, 38], [22, 40]]
# 41
# [2*]C=N[C@@H](CO)c1ccccc1.[2*]c1ccccc1OC(C)=O.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [4388, 3855]
# attachment points [8, 10]
# [[1]]
# [[1, 31]]
# [[1, 31], [13]]
# [[1, 31], [13, 33]]
# 42
# [8*]/C=N\n1c(C)nnc1C.[8*]C(=O)NCCCCCCN.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [5174, 5567]
# attachment points [0, 8]
# [[1]]
# [[1, 21]]
# [[1, 21], [11]]
# [[1, 21], [11, 29]]
# 43
# *C[n+]1ccc(-c2cc[n+](CCC(=O)NC3CC(C)(C)[N+](=O)C(C)(C)C3)cc2)cc1.[10*]OCCOCCO.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [5594, 4119]
# attachment points [10, 8]
# [[1]]
# [[1, 48]]
# [[1, 48], [31]]
# [[1, 48], [31, 46]]
# 44
# [1*]C#Cc1ccc(CCCCC)cc1.[9*]C(=O)OC1CC[C@@]2(C)C(=CC[C@@H]3[C@@H]2CC[C@@]2(C)[C@H]3CC[C@@H]2[C@H](C)CCCC(C)C)C1.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [1303, 4924]
# attachment points [10, 8]
# [[1]]
# [[1, 55]]
# [[1, 55], [15]]
# [[1, 55], [15, 53]]
# 45
# *c1ccc(-c2ccc(SC(CCC)(CCC)CCC)s2)s1.[8*]/C=C/c1ccc(SC)cc1.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [4612, 1866]
# attachment points [10, 9]
# [[1]]
# [[1, 43]]
# [[1, 43], [23]]
# [[1, 43], [23, 42]]
# 46
# [2*]C(O)(c1ccccn1)C(C)(C)C.[7*][C@H](O)C(C)(C)C.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [1348, 3066]
# attachment points [10, 9]
# [[1]]
# [[1, 30]]
# [[1, 30], [14]]
# [[1, 30], [14, 29]]
# 47
# */C=C/c1ccc(N(c2ccc(-c3ccc(N(c4ccccc4)c4cccc(C)c4)cc3)cc2)c2cccc(C)c2)cc1.*C(=O)NCCCCCCCCCC.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [4536, 404]
# attachment points [10, 1]
# [[1]]
# [[1, 67]]
# [[1, 67], [44]]
# [[1, 67], [44, 58]]
# 48
# *CCCC(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)F.[9*]C(Br)Br.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [3746, 5402]
# attachment points [9, 7]
# [[1]]
# [[1, 42]]
# [[1, 42], [30]]
# [[1, 42], [30, 40]]
# 49
# [1*]C(=O)N1CC2CC3CC(C2)CC1C3.[8*]CCC(=O)OC.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [3688, 2076]
# attachment points [1, 7]
# [[1]]
# [[1, 22]]
# [[1, 22], [15]]
# [[1, 22], [15, 28]]
# 50
# [2*]NC(C)=O.[9*]C#Cc1ccc(C(=O)N(CC)CC)cc1.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [3183, 188]
# attachment points [0, 10]
# [[1]]
# [[1, 21]]
# [[1, 21], [6]]
# [[1, 21], [6, 31]]
# 51
# [7*]O[P+]([S-])(c1ccccc1)c1ccccc1.[9*]CCCCc1cccc(O)c1O.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [
CC(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)C(F)(F)F.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [2857, 2687]
# attachment points [5, 2]
# [[1]]
# [[1, 57]]
# [[1, 57], [23]]
# [[1, 57], [23, 54]]
# 63
# [1*]C#Cc1cn([C@H]2C[C@H](O)[C@@H](CO)O2)c2ncnc(N)c12.[10*]c1ccc(OCCO)cc1.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [3191, 5551]
# attachment points [7, 1]
# [[1]]
# [[1, 39]]
# [[1, 39], [22]]
# [[1, 39], [22, 33]]
# 64
# *C(=O)Oc1c(F)c(F)c(F)c(F)c1F.[8*]NC(=O)CCOC.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [2286, 465]
# attachment points [7, 2]
# [[1]]
# [[1, 30]]
# [[1, 30], [16]]
# [[1, 30], [16, 25]]
# 65
# [5*]CCCC/C=C/C.[9*]C(=O)Oc1ccc(OC(=O)c2ccc(OCCCCCCCC)cc2)cc1.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [3163, 1256]
# attachment points [2, 0]
# [[1]]
# [[1, 38]]
# [[1, 38], [9]]
# [[1, 38], [9, 36]]
# 66
# *Cc1ccccc1.[7*]N[P+]([Se-])(c1ccccc1)c1ccccc1.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [1575, 5313]
# attachment points [5, 2]
# [[1]]
# [[1, 29]]
# [[1, 29], [9]]
# [[1, 29], [9, 26]]
# 67
# *C#Cc1ccc(N)cc1.[8*]/C=C/C(=O)OC.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [4027, 3327]
# attachment points [10, 0]
# [[1]]
# [[1, 27]]
# [[1, 27], [11]]
# [[1, 27], [11, 17]]
# 68
# *C(=O)NCCO.[10*]C(=O)ON1C(=O)CCC1=O.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [2745, 1281]
# attachment points [8, 7]
# [[1]]
# [[1, 26]]
# [[1, 26], [8]]
# [[1, 26], [8, 25]]
# 69
# *C(=O)N(CCCC)CCCC.[1*]/C=C/C(=O)OCCCC.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [2393, 4669]
# attachment points [8, 5]
# [[1]]
# [[1, 30]]
# [[1, 30], [13]]
# [[1, 30], [13, 27]]
# 70
# [10*]c1c(O)cc(C)cc1OC.[2*]C([CH2])(C)C.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [1953, 4143]
# attachment points [7, 0]
# [[1]]
# [[1, 23]]
# [[1, 23], [12]]
# [[1, 23], [12, 16]]
# 71
# [1*]C(O)=[NH+]C(CC(O)=[NH+]C[n+]1ccc(-c2cc[n+](C)cc2)cc1)C(O)=[NH+]C(C(=O)N=[n+]1ccc(=C2C=CN(C)C=C2)cc1)C(=O)N=[n+]1ccc(=C2C=CN(C)C=C2)cc1.[2*]C(=C)C.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [2616, 5086]
# attachment points [10, 2]
# [[1]]
# [[1, 73]]
# [[1, 73], [60]]
# [[1, 73], [60, 65]]
# 72
# [2*]C#CC12OC3C4(CCCO4)C(O1)C1(CCCO1)C(O2)C31CCCO1.[8*]C#C/C(C)=C/CO.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [4478, 2549]
# attachment points [0, 7]
# [[1]]
# [[1, 33]]
# [[1, 33], [26]]
# [[1, 33], [26, 40]]
# 73
# [10*]CN.[8*]CCCC=C.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [1587, 366]
# attachment points [1, 0]
# [[1]]
# [[1, 10]]
# [[1, 10], [4]]
# [[1, 10], [4, 9]]
# 74
# [1*]C(=O)O[C@@H]1CC[C@]2(C)[C@H]3C[C@H](OC(=O)CSC(=S)N(CC)CC)[C@@]4(C)[C@@H](CC[C@@H]4[C@H](C)CCC(=O)N(CCCCCCCC)CCCCCCCC)[C@@H]3CC[C@@H]2C1.[7*]P(=O)(c1ccccc1)c1ccccc1.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [2600, 400]
# attachment points [0, 7]
# [[1]]
# [[1, 73]]
# [[1, 73], [59]]
# [[1, 73], [59, 80]]
# 75
# *CNCCCC.*c1cc2c(s1)-c1sc(CCCCCC)cc1C2(CCCCCC)CCCCCC.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [3613, 1839]
# attachment points [2, 0]
# [[1]]
# [[1, 39]]
# [[1, 39], [8]]
# [[1, 39], [8, 37]]
# 76
# */C=C/c1cc(OC)ccc1OC.*/C=C/c1ccc(N(C)C)s1.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [305, 2423]
# attachment points [10, 1]
# [[1]]
# [[1, 34]]
# [[1, 34], [14]]
# [[1, 34], [14, 25]]
# 77
# [10*]C1=N[C@@H]2CCC[C@@H]2C1.[2*]c1nnc(CBr)c(CBr)n1.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [1015, 5177]
# attachment points [2, 5]
# [[1]]
# [[1, 22]]
# [[1, 22], [10]]
# [[1, 22], [10, 25]]
# 78
# *C=Cc1cc(OC)ccc1OC.[8*]CC(NC(=O)OC(C)(C)C)C(=O)O.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [947, 597]
# attachment points [1, 2]
# [[1]]
# [[1, 28]]
# [[1, 28], [14]]
# [[1, 28], [14, 29]]
# 79
# [1*]c1cc(OC)c(-c2cc(OC)c(N3c4ccccc4Sc4ccccc43)cc2OC)cc1OC.[2*]Br.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [364, 4350]
# attachment points [9, 1]
# [[1]]
# [[1, 46]]
# [[1, 46], [36]]
# [[1, 46], [36, 38]]
# 80
# [1*]C#Cc1ccc(C#Cc2ccccc2C#Cc2ccc(C(c3ccc(C#Cc4ccc(-c5c6nc(c(-c7c(C)cc(C)cc7C)c7ccc([nH]7)c(-c7c(C)cc(C)cc7C)c7nc(c(-c8c(C)cc(C)cc8C)c8ccc5[nH]8)C=C7)C=C6)cc4)cc3)(c3ccc(C#Cc4c(C)c(C)c(-c5ccc6ccc7ccc(-c8c(C)cc(C)cc8C)nc7c6n5)c(C)c4C)cc3)c3ccc(C#C[Si](C)(C)C)cc3)cc2)cc1.[2*]c1nn[nH]n1.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [386, 5120]
# attachment points [9, 5]
# [[1]]
# [[1, 159]]
# [[1, 159], [145]]
# [[1, 159], [145, 155]]
# 81
# *c1ccc(-c2cc(C3=C(c4cc(-c5ccccc5)sc4C)CCC3)c(C)s2)cc1.[10*]c1nc2cc([N+](=O)[O-])c([N+](=O)[O-])cc2nc1-c1ccccn1.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [4439, 4351]
# attachment points [0, 7]
# [[1]]
# [[1, 53]]
# [[1, 53], [31]]
# [[1, 53], [31, 60]]
# 82
# [10*]C(=O)N(Br)Br.[2*]C1=NN(C(C)C)C(=O)N(C(C)C)[N]1.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [2920, 1150]
# attachment points [8, 9]
# [[1]]
# [[1, 28]]
# [[1, 28], [7]]
# [[1, 28], [7, 29]]
# 83
# [1*]C(=O)N(C)c1ccc(Oc2ccccc2)cc1.[2*]C(=O)OCC[Si](C)(C)C.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [1909, 3656]
# attachment points [8, 5]
# [[1]]
# [[1, 36]]
# [[1, 36], [19]]
# [[1, 36], [19, 33]]
# 84
# *C([Si](C)(C)C)[Si](C)(C)C.*c1cc2sc(CCCCCCCC)cc2s1.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [
c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [2460, 848]
# attachment points [1, 10]
# [[1]]
# [[1, 33]]
# [[1, 33], [19]]
# [[1, 33], [19, 42]]
# 95
# *CCCCCCCCCC/C=C/C(F)(F)C(F)(F)C(F)(F)C(F)(F)F.[2*]/C(S)=C/S.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [3819, 3937]
# attachment points [1, 10]
# [[1]]
# [[1, 32]]
# [[1, 32], [27]]
# [[1, 32], [27, 41]]
# 96
# */C=C/c1ccc(/C=C/c2ccc(N(C)C)cc2)cc1.[2*]C(OC(C)=O)C(C)C.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [3781, 4902]
# attachment points [5, 10]
# [[1]]
# [[1, 34]]
# [[1, 34], [21]]
# [[1, 34], [21, 39]]
# 97
# [1*][Si](C)(C)C(C)(C)C.[8*]c1c(OCCCCCCCC)cccc1OCCCCCCCC.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [1469, 311]
# attachment points [8, 0]
# [[1]]
# [[1, 41]]
# [[1, 41], [9]]
# [[1, 41], [9, 33]]
# 98
# [1*]Oc1ccccc1OC.[2*]C.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [46, 3665]
# attachment points [9, 10]
# [[1]]
# [[1, 21]]
# [[1, 21], [11]]
# [[1, 21], [11, 22]]
# 99
# [1*]P(=O)(c1ccccc1)c1ccccc1.[10*]NCCCN.c1cc[n+]2c(c1)-c1cccc[n+]1[Re]2
# sidechaines [3060, 3546]
# attachment points [9, 7]
# [[1]]
# [[1, 30]]
# [[1, 30], [16]]
# [[1, 30], [16, 28]]
# RDKit ERROR: [15:40:31] UFFTYPER: Unrecognized atom type: Re6 (25)
# RDKit ERROR: [15:40:31] UFFTYPER: Unrecognized atom type: Re6 (34)
# RDKit ERROR: [15:40:31] UFFTYPER: Unrecognized atom type: Re6 (22)
# RDKit ERROR: [15:40:31] UFFTYPER: Unrecognized atom type: Re6 (34)
# RDKit ERROR: [15:40:32] UFFTYPER: Unrecognized atom type: Re6 (41)
# RDKit ERROR: [15:40:32] UFFTYPER: Unrecognized atom type: Re6 (34)
# RDKit ERROR: [15:40:32] UFFTYPER: Unrecognized atom type: Re6 (41)
# RDKit ERROR: [15:40:33] UFFTYPER: Unrecognized atom type: Re6 (34)
# RDKit ERROR: [15:40:33] UFFTYPER: Unrecognized atom type: Re6 (73)
# RDKit ERROR: [15:40:34] UFFTYPER: Unrecognized atom type: Re6 (99)
# RDKit ERROR: [15:40:36] UFFTYPER: Unrecognized atom type: Re6 (23)
# RDKit ERROR: [15:40:36] UFFTYPER: Unrecognized atom type: Re6 (56)
# RDKit ERROR: [15:40:37] UFFTYPER: Unrecognized atom type: Re6 (36)
# RDKit ERROR: [15:40:37] UFFTYPER: Unrecognized atom type: Re6 (14)
# RDKit ERROR: [15:40:37] UFFTYPER: Unrecognized atom type: Re6 (12)
# RDKit ERROR: [15:40:38] UFFTYPER: Unrecognized atom type: Re6 (31)
# RDKit ERROR: [15:40:39] UFFTYPER: Unrecognized atom type: Re6 (32)
# RDKit ERROR: [15:40:39] UFFTYPER: Unrecognized atom type: Re6 (28)
# RDKit ERROR: [15:40:39] UFFTYPER: Unrecognized atom type: Re6 (30)
# RDKit ERROR: [15:40:39] UFFTYPER: Unrecognized atom type: Re6 (18)
# RDKit ERROR: [15:40:40] UFFTYPER: Unrecognized atom type: Re6 (59)
# RDKit ERROR: [15:40:41] UFFTYPER: Unrecognized atom type: Re6 (47)
# RDKit ERROR: [15:40:41] UFFTYPER: Unrecognized atom type: Re6 (36)
# RDKit ERROR: [15:40:41] UFFTYPER: Unrecognized atom type: Re6 (43)
# RDKit ERROR: [15:40:43] UFFTYPER: Unrecognized atom type: Re6 (31)
# RDKit ERROR: [15
UFFTYPER: Unrecognized atom type: Re6 (32)
# RDKit ERROR: [15:40:57] UFFTYPER: Unrecognized atom type: Re6 (13)
# RDKit ERROR: [15:40:57] UFFTYPER: Unrecognized atom type: Re6 (40)
# RDKit ERROR: [15:40:57] UFFTYPER: Unrecognized charge state for atom: 0
# RDKit ERROR: [15:40:57] UFFTYPER: Unrecognized charge state for atom: 1
# RDKit ERROR: [15:40:57] UFFTYPER: Unrecognized atom type: Re6 (16)
# RDKit ERROR: [15:40:57] UFFTYPER: Unrecognized atom type: Re6 (27)
# RDKit ERROR: [15:40:57] UFFTYPER: Unrecognized atom type: Re6 (28)
# RDKit ERROR: [15:40:57] UFFTYPER: Unrecognized atom type: Re6 (32)
# RDKit ERROR: [15:40:58] UFFTYPER: Unrecognized atom type: Re6 (26)
# RDKit ERROR: [15:40:58] UFFTYPER: Unrecognized atom type: Re6 (9)
# RDKit ERROR: [15:40:58] UFFTYPER: Unrecognized atom type: Re6 (40)
# RDKit ERROR: [15:40:58] UFFTYPER: Unrecognized atom type: Re6 (13)
# RDKit WARNING: [15:40:58] UFFTYPER: Warning: hybridization set to SP3 for atom 44
# RDKit ERROR: [15:40:58] UFFTYPER: Unrecognized charge state for atom: 44
# RDKit ERROR: [15:40:58] UFFTYPER: Unrecognized atom type: Re6 (62)
# RDKit ERROR: [15:40:59] UFFTYPER: Unrecognized atom type: Re6 (32)
# RDKit ERROR: [15:41:00] UFFTYPER: Unrecognized atom type: Re6 (17)
# RDKit ERROR: [15:41:00] UFFTYPER: Unrecognized atom type: Re6 (26)
# RDKit ERROR: [15:41:00] UFFTYPER: Unrecognized atom type: Re6 (30)
# RDKit ERROR: [15:41:00] UFFTYPER: Unrecognized atom type: Re6 (40)
# RDKit ERROR: [15:41:01] UFFTYPER: Unrecognized atom type: Re6 (120)
# RDKit ERROR: [15:41:04] UFFTYPER: Unrecognized atom type: Re6 (55)
# RDKit ERROR: [15:41:05] UFFTYPER: Unrecognized atom type: Re6 (23)
# RDKit ERROR: [15:41:05] UFFTYPER: Unrecognized atom type: Re6 (25)
# RDKit ERROR: [15:41:05] UFFTYPER: Unrecognized atom type: Re6 (19)
# RDKit ERROR: [15:41:06] UFFTYPER: Unrecognized atom type: Re6 (24)
# RDKit ERROR: [15:41:06] UFFTYPER: Unrecognized atom type: Re6 (94)
# RDKit ERROR: [15:41:08] UFFTYPER: Unrecognized atom type: Re6 (44)
# RDKit ERROR: [15:41:08] UFFTYPER: Unrecognized atom type: Re6 (58)
# RDKit ERROR: [15:41:09] UFFTYPER: Unrecognized atom type: Re6 (9)
# RDKit ERROR: [15:41:10] UFFTYPER: Unrecognized atom type: Re6 (41)
# RDKit ERROR: [15:41:10] UFFTYPER: Unrecognized atom type: Re6 (19)
# RDKit ERROR: [15:41:10] UFFTYPER: Unrecognized atom type: Re6 (68)
# RDKit ERROR: [15:41:12] UFFTYPER: Unrecognized atom type: Re6 (23)
# RDKit ERROR: [15:41:12] UFFTYPER: Unrecognized atom type: Re6 (17)
# RDKit ERROR: [15:41:12] UFFTYPER: Unrecognized atom type: Re6 (31)
# RDKit ERROR: [15:41:12] UFFTYPER: Unrecognized atom type: Re6 (11)
# RDKit ERROR: [15:41:13] UFFTYPER: Unrecognized atom type: Re6 (43)
# RDKit ERROR: [15:41:13] UFFTYPER: Unrecognized atom type: Re6 (16)
# RDKit WARNING: [15:41:13] UFFTYPER: Warning: hybridization set to SP3 for atom 8
# RDKit ERROR: [15:41:13] UFFTYPER: Unrecognized charge state for atom: 8
# RDKit ERROR: [15:41:13] UFFTYPER: Unrecognized atom type: Re6 (31)
# /Users/tarrago/Documents/personal-project

# %%
# We can see that the program complains a lot about the Re, as emphasize above. But the rest of the atoms are decently 
# organized, if not optimized. The xyzfiles are stored in the specified diretory, ready to be used by a QM package,
# or visualized with an appropriate software (chemcraft, chimera, avogadto...)
